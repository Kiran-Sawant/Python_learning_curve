# %%
import pandas as pd
from pandas_datareader import data
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Importing NASDAQ100 ETF Dataset.

nasdaq = data.DataReader('QQQ', data_source='yahoo').drop(columns='Adj Close')
nasdaq
# Out:
#                   High         Low        Open       Close      Volume
# Date
# 2015-07-08  107.330002  105.889999  107.199997  106.089996  39691500.0
# 2015-07-09  107.599998  106.019997  107.500000  106.029999  28381000.0
# 2015-07-10  108.050003  107.050003  107.440002  107.650002  26415800.0
# 2015-07-13  109.629997  108.570000  108.580002  109.540001  25780700.0
# 2015-07-14  110.559998  109.629997  109.690002  110.260002  21977200.0
# ...                ...         ...         ...         ...         ...
# 2020-06-30  248.160004  242.580002  242.770004  247.600006  38909200.0
# 2020-07-01  251.520004  247.080002  247.639999  250.490005  34689200.0
# 2020-07-02  254.270004  251.710007  253.020004  252.190002  31956500.0
# 2020-07-06  258.929993  255.429993  255.449997  258.390015  34310400.0
# 2020-07-07  260.880005  257.540009  255.460007  258.820007  24117691.0
#
# [1259 rows x 5 columns]

# %% [markdown]
# # # df.plot() method

# %%
# ploting values in 'Open' & 'Close' columns.

nasdaq.plot(y=['Open', 'Close'])
plt.show()

# %% [markdown]
# # # Asthetics.

# %%
# list of available asthetics.

plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('tableau-colorblind10')
nasdaq.plot(y=['Open', 'High', 'Low', 'Close'])

# %%
plt.style.use('seaborn-darkgrid')
nasdaq.plot(y=['Open', 'High', 'Low', 'Close'])

# %%
plt.style.use('grayscale')
nasdaq.plot(y=['Open', 'High', 'Low', 'Close'])

# %% [markdown]
# # # Bar-Graphs & Pies.

# %%
nasdaq['Close'].mean()
# Out:
# 154.46683877304113

# %%
def average(n):
    if n < 154.47:
        return 'below average'
    elif n > 150 and n < 160:
        return 'average'
    else:
        return 'above average'

# %%
performance = nasdaq['Close'].apply(average)
performance
# Out:
# Date
# 2015-07-06    below average
# 2015-07-07    below average
# 2015-07-08    below average
# 2015-07-09    below average
# 2015-07-10    below average
#                   ...
# 2020-06-26    above average
# 2020-06-29    above average
# 2020-06-30    above average
# 2020-07-01    above average
# 2020-07-02    above average
# Name: Close, Length: 1259, dtype: object

# %%
performance.value_counts().plot(kind='bar')
plt.show()

# %%
performance.value_counts().plot(kind='barh')
plt.show()

# %%
performance.value_counts().plot(kind='pie', legend=True)
plt.show()
