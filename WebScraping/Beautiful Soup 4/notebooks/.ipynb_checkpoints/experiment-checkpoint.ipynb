# %%
import time
from copy import deepcopy
import json

import requests
from bs4 import BeautifulSoup
import pandas as pd
from tqdm.notebook import tqdm

# %%
# Function for saving html

def save_html(html, path):
    with open(path, mode='wb')as f:
        f.write(html)

# %%
# Function for reading a local html file

def open_html(path):
    with open(path, mode='rb') as f:
        return f.read()

# %% [markdown]
# ## # Sending GET request
#
# Sending a get request and storing the response in response variable

# %%
url = "https://www.allsides.com/media-bias/media-bias-ratings"

response = requests.get(url)

# %%
print(response.content[:100])
# Out:
# b'<!DOCTYPE html>\n<!--[if IEMobile 7]><html class="iem7"  lang="en" dir="ltr"><![endif]-->\n<!--[if lte'

# %% [markdown]
# ## # Creating a soup object
#
# A soup object defines many methods that can be used to find elements and their contents.

# %%
soup = BeautifulSoup(response.content, features='html.parser')

# %%
rows = soup.select("tbody tr")

# %%
# print(rows[0].select_one(".source-title").text.strip())

name = rows[0].select_one(".source-title").text.strip()
name
# Out:
# 'ABC News (Online)'

# %%
# getting the relative URL in href of anchor tag
# use brackets to select HTML attribute values

abc = rows[0].select_one('.source-title a')['href']
abc
# Out:
# '/news-source/abc-news-media-bias'

# %%
# creating an absolute URL

allsides_abcpage = "https://www.allsides.com" + abc

allsides_abcpage
# Out:
# https://www.allsides.com/news-source/abc-news-media-bias

# %% [markdown]
# ### Getting political bias info

# %%
rows[0].select_one(".views-field-field-bias-image a")['href'].split('/')[-1]
# Out:
# 'left-center'

# %%
bias = rows[0].select_one(".views-field-field-bias-image a")['href'].split('/')[-1]
bias
# Out:
# 'left-center'

# %%
agree = int(rows[0].select_one('.agree').text)
agree
# Out:
# 32966

# %%
disagree = int(rows[0].select_one('.disagree').text)
disagree
# Out:
# 16881

# %%
agree_ratio = agree/ disagree
agree_ratio
# Out:
# 1.9528463953557254

# %%
print(f"Agree: {agree}, disagree: {disagree}, ratio: {agree_ratio: .2f}")
# Out:
# Agree: 32966, disagree: 16881, ratio:  1.95

# %%
def get_agreeance_text(ratio):
    if ratio > 3: return "absolutely agrees"
    elif 2 < ratio <= 3: return "strongly agrees"
    elif 1.5 < ratio <= 2: return "agrees"
    elif 1 < ratio <= 1.5: return "somewhat agrees"
    elif ratio == 1: return "neutral"
    elif 0.67 < ratio < 1: return "somewhat disagrees"
    elif 0.5 < ratio <= 0.67: return "disagrees"
    elif 0.33 < ratio <= 0.5: return "strongly disagree"
    elif ratio <= 0.33: return "absolutly disagrees"
    else: return None

# %%
data = list()

for row in rows:
    
    d = dict()
    d['name'] = row.select_one('.source-title').text.strip()
    d['allsides_page'] = "https://www.allsides.com" + row.select_one('.source-title a')['href']
    d['bias'] = row.select_one(".views-field-field-bias-image a")['href'].split('/')[-1]
    d['agree'] = int(row.select_one('.agree').text)
    d['disagree'] = int(row.select_one('.disagree').text)
    d['agree_ratio'] = d['agree'] / d['disagree']
    d['agreeance_text'] = get_agreeance_text(d['agree_ratio'])
    
    data.append(d)

# %%
data
# Out:
# [{'name': 'ABC News (Online)',
#   'allsides_page': 'https://www.allsides.com/news-source/abc-news-media-bias',
#   'bias': 'left-center',
#   'agree': 32966,
#   'disagree': 16881,
#   'agree_ratio': 1.9528463953557254,
#   'agreeance_text': 'agrees'},
#  {'name': 'AlterNet',
#   'allsides_page': 'https://www.allsides.com/news-source/alternet-media-bias',
#   'bias': 'left',
#   'agree': 12408,
#   'disagree': 2536,
#   'agree_ratio': 4.892744479495268,
#   'agreeance_text': 'absolutely agrees'},
#  {'name': 'AP Politics & Fact Check',
#   'allsides_page': 'https://www.allsides.com/news-source/ap-fact-check-media-bias',
#   'bias': 'left-center',
#   'agree': 3680,
#   'disagree': 4441,
#   'agree_ratio': 0.82864219770322,
#   'agreeance_text': 'somewhat disagrees'},
#  {'name': 'Associated Press',
#   'allsides_page': 'https://www.allsides.com/news-source/associated-press-media-bias',
#   'bias': 'center',
#   'agree': 24763,
#   'disagree': 18518,
#   'agree_ratio': 1.3372394427043957,
#   'agreeance_text': 'somewhat agrees'},
#  {'name': 'Axios',
#   'allsides_page': 'https://www.allsides.com/news-source/axios',
#   'bias': 'center',
#   'agree': 5087,
#   'disagree': 5346,
#   'agree_ratio': 0.9515525626636738,
#   'agreeance_text': 'somewhat disagrees'},
#  {'name': 'BBC News',
#   'allsides_page': 'https://www.allsides.com/news-source/bbc-news-media-bias',
#   'bias': 'center',
#   'agree': 27407,
#   'disagree': 23422,
#   'agree_ratio': 1.1701391853812655,
#   'agreeance_text': 'somewhat agrees'},
#  {'name': 'Bloomberg',
#   'allsides_page': 'https://www.allsides.com/news-source/bloomberg-media-bias',
#   'bias': 'left-center',
#   'agree': 14801,
#   'disagree': 20194,
#   'agree_ratio': 0.7329404773695157,
#   'agreeance_text': 'somewhat disagrees'},
#  {'name': 'Breitbart News',
#   'allsides_page': 'https://www.allsides.com/news-source/breitbart',
#   'bias': 'right',
#   'agree': 37060,
#   'disagree': 10790,
#   'agree_ratio': 3.4346617238183503,
#   'agreeance_text': 'absolutely agrees'},
#  {'name': 'BuzzFeed News',
#   'allsides_page': 'https://www.allsides.com/news-source/buzzfeed-media-bias',
#   'bias': 'left',
#   'agree': 22596,
#   'disagree': 8890,
#   'agree_ratio': 2.541732283464567,
#   'agreeance_text': 'strongly agrees'},
#  {'name': 'CBS News (Online)',
#   'allsides_page': 'https://www.allsides.com/news-source/cbs-news-media-bias',
#   'bias': 'left-center',
#   'agree': 17767,
#   'disagree': 11370,
#   'agree_ratio': 1.5626209322779243,
#   'agreeance_text': 'agrees'},
#  {'name': 'Christian Science Monitor',
#   'allsides_page': 'https://www.allsides.com/news-source/christian-science-monitor',
#   'bias': 'center',
#   'agree': 14789,
#   'disagree': 18428,
#   'agree_ratio': 0.8025287605817235,
#   'agreeance_text': 'somewhat disagrees'},
#  {'name': 'CNN (Online News)',
#   'allsides_page': 'https://www.allsides.com/news-source/cnn-media-bias',
#   'bias': 'left',
#   'agree': 47454,
#   'disagree': 46523,
#   'agree_ratio': 1.0200116071620489,
#   'agreeance_text': 'somewhat agrees'},
#  {'name': 'CNN (Opinion)',
#   'allsides_page': 'https://www.allsides.com/news-source/cnn-editorial',
#   'bias': 'left',
#   'agree': 30502,
#   'disagree': 6731,
#   'agree_ratio': 4.53157034615956,
#   'agreeance_text': 'absolutely agrees'},
#  {'name': 'Daily Beast',
#   'allsides_page': 'https://www.allsides.com/news-source/daily-beast-media-bias',
#   'bias': 'left',
#   'agree': 17932,
#   'disagree': 5805,
#   'agree_ratio': 3.089061154177433,
#   'agreeance_text': 'absolutely agrees'},
#  {'name': 'Daily Mail',
#   'allsides_page': 'https://www.allsides.com/news-source/daily-mail',
#   'bias': 'right',
#   'agree': 10658,
#   'disagree': 5863,
#   'agree_ratio': 1.8178406958894764,
#   'agreeance_text': 'agrees'},
#  {'name': 'Democracy Now',
#   'allsides_page': 'https://www.allsides.com/news-source/democracy-now',
#   'bias': 'left',
#   'agree': 12368,
#   'disagree': 2827,
#   'agree_ratio': 4.374955783516095,
#   'agreeance_text': 'absolutely agrees'},
#  {'name': 'Forbes',
#   'allsides_page': 'https://www.allsides.com/news-source/forbes',
#   'bias': 'center',
#   'agree': 12578,
#   'disagree': 7398,
#   'agree_ratio': 1.7001892403352257,
#   'agreeance_text': 'agrees'},
#  {'name': 'Fox News (Online News)',
#   'allsides_page': 'https://www.allsides.com/news-source/fox-news-media-bias',
#   'bias': 'right-center',
#   'agree': 39019,
#   'disagree': 45742,
#   'agree_ratio': 0.8530234795155437,
#   'agreeance_text': 'somewhat disagrees'},
#  {'name': 'Fox News (Opinion)',
#   'allsides_page': 'https://www.allsides.com/news-source/fox-news-editorial-media-bias',
#   'bias': 'right',
#   'agree': 25300,
#   'disagree': 5921,
#   'agree_ratio': 4.27292687046107,
#   'agreeance_text': 'absolutely agrees'},
#  {'name': 'HuffPost',
#   'allsides_page': 'https://www.allsides.com/news-source/huffpost-media-bias',
#   'bias': 'left',
#   'agree': 33936,
#   'disagree': 21964,
#   'agree_ratio': 1.5450737570570023,
#   'agreeance_text': 'agrees'},
#  {'name': 'Mother Jones',
#   'allsides_page': 'https://www.allsides.com/news-source/mother-jones-bias',
#   'bias': 'left',
#   'agree': 14152,
#   'disagree': 2055,
#   'agree_ratio': 6.88661800486618,
#   'agreeance_text': 'absolutely agrees'},
#  {'name': 'MSNBC',
#   'allsides_page': 'https://www.allsides.com/news-source/msnbc',
#   'bias': 'left',
#   'agree': 19232,
#   'disagree': 5054,
#   'agree_ratio': 3.805302730510487,
#   'agreeance_text': 'absolutely agrees'},
#  {'name': 'National Review',
#   'allsides_page': 'https://www.allsides.com/news-source/national-review',
#   'bias': 'right',
#   'agree': 17718,
#   'disagree': 7218,
#   'agree_ratio': 2.454696591853699,
#   'agreeance_text': 'strongly agrees'},
#  {'name': 'NBC News (Online)',
#   'allsides_page': 'https://www.allsides.com/news-source/nbc-news-media-bias',
#   'bias': 'left-center',
#   'agree': 11194,
#   'disagree': 11166,
#   'agree_ratio': 1.0025076123947698,
#   'agreeance_text': 'somewhat agrees'},
#  {'name': 'New York Post (News)',
#   'allsides_page': 'https://www.allsides.com/news-source/new-york-post',
#   'bias': 'right-center',
#   'agree': 12834,
#   'disagree': 6990,
#   'agree_ratio': 1.8360515021459227,
#   'agreeance_text': 'agrees'},
#  {'name': 'New York Times (News)',
#   'allsides_page': 'https://www.allsides.com/news-source/new-york-times',
#   'bias': 'left-center',
#   'agree': 27468,
#   'disagree': 37179,
#   'agree_ratio': 0.738804163640765,
#   'agreeance_text': 'somewhat disagrees'},
#  {'name': 'New York Times (Opinion)',
#   'allsides_page': 'https://www.allsides.com/news-source/new-york-times-opinion-media-bias',
#   'bias': 'left',
#   'agree': 13010,
#   'disagree': 3506,
#   'agree_ratio': 3.710781517398745,
#   'agreeance_text': 'absolutely agrees'},
#  {'name': 'NPR (Online News)',
#   'allsides_page': 'https://www.allsides.com/news-source/npr-media-bias',
#   'bias': 'center',
#   'agree': 30354,
#   'disagree': 27510,
#   'agree_ratio': 1.103380588876772,
#   'agreeance_text': 'somewhat agrees'},
#  {'name': 'NPR (Opinion)',
#   'allsides_page': 'https://www.allsides.com/news-source/npr-editorial',
#   'bias': 'left-center',
#   'agree': 7563,
#   'disagree': 8434,
#   'agree_ratio': 0.896727531420441,
#   'agreeance_text': 'somewhat disagrees'},
#  {'name': 'Politico',
#   'allsides_page': 'https://www.allsides.com/news-source/politico-media-bias',
#   'bias': 'left-center',
#   'agree': 22315,
#   'disagree': 29205,
#   'agree_ratio': 0.7640814928950522,
#   'agreeance_text': 'somewhat disagrees'},
#  {'name': 'Reason',
#   'allsides_page': 'https://www.allsides.com/news-source/reason',
#   'bias': 'right-center',
#   'agree': 8832,
#   'disagree': 5386,
#   'agree_ratio': 1.6398069067953955,
#   'agreeance_text': 'agrees'},
#  {'name': 'Reuters',
#   'allsides_page': 'https://www.allsides.com/news-source/reuters',
#   'bias': 'center',
#   'agree': 16807,
#   'disagree': 9088,
#   'agree_ratio': 1.849361795774648,
#   'agreeance_text': 'agrees'},
#  {'name': 'Slate',
#   'allsides_page': 'https://www.allsides.com/news-source/slate',
#   'bias': 'left',
#   'agree': 8725,
#   'disagree': 3313,
#   'agree_ratio': 2.6335647449441595,
#   'agreeance_text': 'strongly agrees'},
#  {'name': 'The American Spectator',
#   'allsides_page': 'https://www.allsides.com/news-source/american-spectator',
#   'bias': 'right',
#   'agree': 11487,
#   'disagree': 3956,
#   'agree_ratio': 2.903690596562184,
#   'agreeance_text': 'strongly agrees'},
#  {'name': 'The Atlantic',
#   'allsides_page': 'https://www.allsides.com/news-source/atlantic',
#   'bias': 'left-center',
#   'agree': 13596,
#   'disagree': 7210,
#   'agree_ratio': 1.8857142857142857,
#   'agreeance_text': 'agrees'},
#  {'name': 'The Daily Caller',
#   'allsides_page': 'https://www.allsides.com/news-source/daily-caller',
#   'bias': 'right',
#   'agree': 9314,
#   'disagree': 3734,
#   'agree_ratio': 2.494376004284949,
#   'agreeance_text': 'strongly agrees'},
#  {'name': 'The Daily Wire',
#   'allsides_page': 'https://www.allsides.com/news-source/daily-wire',
#   'bias': 'right',
#   'agree': 9497,
#   'disagree': 3424,
#   'agree_ratio': 2.7736565420560746,
#   'agreeance_text': 'strongly agrees'},
#  {'name': 'The Economist',
#   'allsides_page': 'https://www.allsides.com/news-source/economist',
#   'bias': 'left-center',
#   'agree': 5243,
#   'disagree': 9243,
#   'agree_ratio': 0.5672400735691875,
#   'agreeance_text': 'disagrees'},
#  {'name': 'The Epoch Times',
#   'allsides_page': 'https://www.allsides.com/news-source/epoch-times-media-bias',
#   'bias': 'right-center',
#   'agree': 10348,
#   'disagree': 4583,
#   'agree_ratio': 2.2579096661575386,
#   'agreeance_text': 'strongly agrees'},
#  {'name': 'The Federalist',
#   'allsides_page': 'https://www.allsides.com/news-source/federalist',
#   'bias': 'right',
#   'agree': 8334,
#   'disagree': 2536,
#   'agree_ratio': 3.2862776025236595,
#   'agreeance_text': 'absolutely agrees'},
#  {'name': 'The Guardian',
#   'allsides_page': 'https://www.allsides.com/news-source/guardian',
#   'bias': 'left-center',
#   'agree': 12592,
#   'disagree': 7520,
#   'agree_ratio': 1.674468085106383,
#   'agreeance_text': 'agrees'},
#  {'name': 'The Hill',
#   'allsides_page': 'https://www.allsides.com/news-source/hill-media-bias',
#   'bias': 'center',
#   'agree': 14972,
#   'disagree': 19698,
#   'agree_ratio': 0.760077165194436,
#   'agreeance_text': 'somewhat disagrees'},
#  {'name': 'The Intercept',
#   'allsides_page': 'https://www.allsides.com/news-source/intercept',
#   'bias': 'left',
#   'agree': 4851,
#   'disagree': 1379,
#   'agree_ratio': 3.517766497461929,
#   'agreeance_text': 'absolutely agrees'},
#  {'name': 'The New Yorker',
#   'allsides_page': 'https://www.allsides.com/news-source/new-yorker',
#   'bias': 'left',
#   'agree': 8533,
#   'disagree': 2038,
#   'agree_ratio': 4.186947988223749,
#   'agreeance_text': 'absolutely agrees'},
#  {'name': 'TheBlaze.com',
#   'allsides_page': 'https://www.allsides.com/news-source/theblaze-bias',
#   'bias': 'right',
#   'agree': 96689,
#   'disagree': 78493,
#   'agree_ratio': 1.2318168499101831,
#   'agreeance_text': 'somewhat agrees'},
#  {'name': 'Time Magazine',
#   'allsides_page': 'https://www.allsides.com/news-source/time-magazine-news-media-bias',
#   'bias': 'left-center',
#   'agree': 8725,
#   'disagree': 7275,
#   'agree_ratio': 1.1993127147766323,
#   'agreeance_text': 'somewhat agrees'},
#  {'name': 'USA TODAY',
#   'allsides_page': 'https://www.allsides.com/news-source/usa-today-media-bias',
#   'bias': 'center',
#   'agree': 17470,
#   'disagree': 19402,
#   'agree_ratio': 0.9004226368415628,
#   'agreeance_text': 'somewhat disagrees'},
#  {'name': 'Vox',
#   'allsides_page': 'https://www.allsides.com/news-source/vox-news-media-bias',
#   'bias': 'left',
#   'agree': 27669,
#   'disagree': 14692,
#   'agree_ratio': 1.8832698066975224,
#   'agreeance_text': 'agrees'},
#  {'name': 'Wall Street Journal (News)',
#   'allsides_page': 'https://www.allsides.com/news-source/wall-street-journal-media-bias',
#   'bias': 'center',
#   'agree': 20670,
#   'disagree': 23925,
#   'agree_ratio': 0.8639498432601881,
#   'agreeance_text': 'somewhat disagrees'},
#  {'name': 'Wall Street Journal (Opinion)',
#   'allsides_page': 'https://www.allsides.com/news-source/wall-street-journal-opinion',
#   'bias': 'right-center',
#   'agree': 10252,
#   'disagree': 6898,
#   'agree_ratio': 1.48622789214265,
#   'agreeance_text': 'somewhat agrees'}]

# %%
pages = [
    'https://www.allsides.com/media-bias/media-bias-ratings',
    'https://www.allsides.com/media-bias/media-bias-ratings?page=1'
]

# %%
data = list()
n = 1
for page in pages:
     
    r = requests.get(page)
    soup = BeautifulSoup(r.content, 'html.parser')
    rows = soup.select("tbody tr")

    for row in rows:

        d = dict()
        
        d['name'] = row.select_one('.source-title').text.strip()
        d['allsides_page'] = "https://www.allsides.com" + row.select_one('.source-title a')['href']
        d['bias'] = row.select_one(".views-field-field-bias-image a")['href'].split('/')[-1]
        d['agree'] = int(row.select_one('.agree').text)
        d['disagree'] = int(row.select_one('.disagree').text)
        d['agree_ratio'] = d['agree'] / d['disagree']
        d['agreeance_text'] = get_agreeance_text(d['agree_ratio'])

        data.append(d)
    print(f"loop {n}")
    n += 1
    time.sleep(10)
print("done")
# Out:
# loop 1
# loop 2
# done

# %%
data[0]
# Out:
# {'name': 'ABC News (Online)',
#  'allsides_page': 'https://www.allsides.com/news-source/abc-news-media-bias',
#  'bias': 'left-center',
#  'agree': 32972,
#  'disagree': 16882,
#  'agree_ratio': 1.9530861272361095,
#  'agreeance_text': 'agrees'}

# %%
# Getting the news provider detail page

response = requests.get(data[0]['allsides_page'])

# %%
# Getting the URL to home page of the news provider

k_soup = BeautifulSoup(response.content, 'html.parser')
web_url = k_soup.select_one('.dynamic-grid a')['href']
web_url
# Out:
# 'http://abcnews.go.com/'

# %%
pd.DataFrame(data)
# Out:
#                              name  \
# 0               ABC News (Online)
# 1                        AlterNet
# 2        AP Politics & Fact Check
# 3                Associated Press
# 4                           Axios
# 5                        BBC News
# 6                       Bloomberg
# 7                  Breitbart News
# 8                   BuzzFeed News
# 9               CBS News (Online)
# 10      Christian Science Monitor
# 11              CNN (Online News)
# 12                  CNN (Opinion)
# 13                    Daily Beast
# 14                     Daily Mail
# 15                  Democracy Now
# 16                         Forbes
# 17         Fox News (Online News)
# 18             Fox News (Opinion)
# 19                       HuffPost
# 20                   Mother Jones
# 21                          MSNBC
# 22                National Review
# 23              NBC News (Online)
# 24           New York Post (News)
# 25          New York Times (News)
# 26       New York Times (Opinion)
# 27              NPR (Online News)
# 28                  NPR (Opinion)
# 29                       Politico
# 30                         Reason
# 31                        Reuters
# 32                          Slate
# 33         The American Spectator
# 34                   The Atlantic
# 35               The Daily Caller
# 36                 The Daily Wire
# 37                  The Economist
# 38                The Epoch Times
# 39                 The Federalist
# 40                   The Guardian
# 41                       The Hill
# 42                  The Intercept
# 43                 The New Yorker
# 44                   TheBlaze.com
# 45                  Time Magazine
# 46                      USA TODAY
# 47                            Vox
# 48     Wall Street Journal (News)
# 49  Wall Street Journal (Opinion)
# 50            Washington Examiner
# 51                Washington Post
# 52               Washington Times
#
#                                         allsides_page          bias  agree  \
# 0   https://www.allsides.com/news-source/abc-news-...   left-center  32972
# 1   https://www.allsides.com/news-source/alternet-...          left  12412
# 2   https://www.allsides.com/news-source/ap-fact-c...   left-center   3683
# 3   https://www.allsides.com/news-source/associate...        center  24766
# 4          https://www.allsides.com/news-source/axios        center   5089
# 5   https://www.allsides.com/news-source/bbc-news-...        center  27413
# 6   https://www.allsides.com/news-source/bloomberg...   left-center  14804
# 7      https://www.allsides.com/news-source/breitbart         right  37067
# 8   https://www.allsides.com/news-source/buzzfeed-...          left  22603
# 9   https://www.allsides.com/news-source/cbs-news-...   left-center  17770
# 10  https://www.allsides.com/news-source/christian...        center  14790
# 11  https://www.allsides.com/news-source/cnn-media...          left  47462
# 12  https://www.allsides.com/news-source/cnn-edito...          left  30509
# 13  https://www.allsides.com/news-source/daily-bea...          left  17934
# 14    https://www.allsides.com/news-source/daily-mail         right  10659
# 15  https://www.allsides.com/news-source/democracy...          left  12371
# 25     37186     0.738719  somewhat disagrees
# 26      3508     3.709806   absolutely agrees
# 27     27515     1.103289     somewhat agrees
# 28      8438     0.896658  somewhat disagrees
# 29     29209     0.764045  somewhat disagrees
# 30      5387     1.640059              agrees
# 31      9089     1.849268              agrees
# 32      3313     2.634168     strongly agrees
# 33      3959     2.901743     strongly agrees
# 34      7214     1.884807              agrees
# 35      3736     2.493308     strongly agrees
# 36      3425     2.773431     strongly agrees
# 37      9247     0.566995           disagrees
# 38      4584     2.258726     strongly agrees
# 39      2538     3.285264   absolutely agrees
# 40      7522     1.674156              agrees
# 41     19702     0.759974  somewhat disagrees
# 42      1380     3.515942   absolutely agrees
# 43      2038     4.187929   absolutely agrees
# 44     78497     1.231805     somewhat agrees
# 45      7276     1.199285     somewhat agrees
# 46     19405     0.900335  somewhat disagrees
# 47     14692     1.883678              agrees
# 48     23930     0.863895  somewhat disagrees
# 49      6899     1.486592     somewhat agrees
# 50      5133     2.190337     strongly agrees
# 51     23022     1.499088     somewhat agrees
# 52     12945     2.098725     strongly agrees

# %%
loop = 0
for d in tqdm(data):
    r = requests.get(d['allsides_page'])
    soup = BeautifulSoup(r.content, 'html.parser')
    
    try:
        web_url = soup.select_one(".dynamic-grid a")['href']
        d['website'] = web_url
    except TypeError:
        pass
    
    print(f"Loop: {loop}")
    loop += 1
    time.sleep(10)
# Out:
#   0%|          | 0/53 [00:00<?, ?it/s]
# Loop: 0
# Loop: 1
# Loop: 2
# Loop: 3
# Loop: 4
# Loop: 5
# Loop: 6
# Loop: 7
# Loop: 8
# Loop: 9
# Loop: 10
# Loop: 11
# Loop: 12
# Loop: 13
# Loop: 14
# Loop: 15
# Loop: 16
# Loop: 17
# Loop: 18
# Loop: 19
# Loop: 20
# Loop: 21
# Loop: 22
# Loop: 23
# Loop: 24
# Loop: 25
# Loop: 26
# Loop: 27
# Loop: 28
# Loop: 29
# Loop: 30
# Loop: 31
# Loop: 32
# Loop: 33
# Loop: 34
# Loop: 35
# Loop: 36
# Loop: 37
# Loop: 38
# Loop: 39
# Loop: 40
# Loop: 41
# Loop: 42
# Loop: 43
# Loop: 44
# Loop: 45
# Loop: 46
# Loop: 47
# Loop: 48
# Loop: 49
# Loop: 50
# Loop: 51
# Loop: 52

# %%
# saving our list of dictionaries in a JSON file.

with open('allsides.json', 'w') as f:
    json.dump(data, f)

# %%
# Reading from the saved JSON file above.

with open('allsides.json', 'r') as f:
    k = json.load(f)

print(k)
# Out:
# [{'name': 'ABC News (Online)', 'allsides_page': 'https://www.allsides.com/news-source/abc-news-media-bias', 'bias': 'left-center', 'agree': 32972, 'disagree': 16882, 'agree_ratio': 1.9530861272361095, 'agreeance_text': 'agrees', 'website': 'http://abcnews.go.com/'}, {'name': 'AlterNet', 'allsides_page': 'https://www.allsides.com/news-source/alternet-media-bias', 'bias': 'left', 'agree': 12412, 'disagree': 2537, 'agree_ratio': 4.892392589672842, 'agreeance_text': 'absolutely agrees', 'website': 'http://www.alternet.org/'}, {'name': 'AP Politics & Fact Check', 'allsides_page': 'https://www.allsides.com/news-source/ap-fact-check-media-bias', 'bias': 'left-center', 'agree': 3683, 'disagree': 4445, 'agree_ratio': 0.8285714285714286, 'agreeance_text': 'somewhat disagrees', 'website':